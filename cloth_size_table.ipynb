# %%
import pandas as pd

# %%
Tabel = pd.read_csv("cloth_data.csv")

# %%
Tabel
# Out:
#     weight   age  height  size
# 0       62  28.0  172.72    XL
# 1       59  36.0  167.64     L
# 2       61  34.0  165.10     M
# 3       65  27.0  175.26     L
# 4       62  45.0  172.72     M
# 5       50  27.0  160.02     S
# 6       53  65.0  160.02     M
# 7       51  33.0  160.02   XXS
# 8       54  26.0  167.64     M
# 9       53  32.0  165.10     S
# 10      63  30.0  170.18  XXXL
# 11      77  35.0  172.72  XXXL
# 12      64  26.0  165.10     L
# 13      52  28.0  160.02     M
# 14      65  33.0  165.10     L
# 15      63  30.0  167.64     L
# 16      54  21.0  167.64   XXS
# 17      63  27.0  172.72     M
# 18      63  30.0  167.64     M
# 19      54  20.0  167.64     S
# 20      55  32.0  154.94     S
# 21      55  37.0  160.02     M
# 22      55  50.0  165.10     S
# 23      50  43.0  160.02     M
# 24      74  29.0  177.80    XL
# 25      64  32.0  160.02    XL
# 26      58  29.0  167.64   XXS
# 27      54  47.0  165.10     M
# 28      58  31.0  154.94    XL
# ...
